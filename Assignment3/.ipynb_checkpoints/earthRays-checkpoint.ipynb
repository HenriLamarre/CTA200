# %%
# A few imports
import make_light_ray_plots as mk
import numpy as np

# %%
dm_list = []
for i in range(24):
    dm_list.append(mk.make_light_ray_plots('test1', ray_direction=[0, 5*np.cos(i/24.*2*np.pi),
                                                                   5*np.sin(i/24.*2*np.pi)]))
# Out:
# yt : [INFO     ] 2020-05-25 15:49:30,478 Calculating time from 1.000e+00 to be 4.355e+17 seconds
# yt : [INFO     ] 2020-05-25 15:49:30,479 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2020-05-25 15:49:30,504 Parameters: current_time              = 4.3545571088051386e+17 s
# yt : [INFO     ] 2020-05-25 15:49:30,505 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2020-05-25 15:49:30,506 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-05-25 15:49:30,508 Parameters: domain_right_edge         = [60000. 60000. 60000.]
# yt : [INFO     ] 2020-05-25 15:49:30,510 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2020-05-25 15:49:30,511 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2020-05-25 15:49:30,512 Parameters: omega_lambda              = 0.728
# yt : [INFO     ] 2020-05-25 15:49:30,513 Parameters: omega_matter              = 0.272
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(np.arange(len(dm_list)), dm_list)
plt.show()
