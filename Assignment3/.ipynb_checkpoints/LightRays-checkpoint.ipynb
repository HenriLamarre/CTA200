# %%
# A few imports
import yt
import numpy as np
import trident
import matplotlib.pyplot as pl
from yt.units import kpc,mp
from yt.fields.particle_fields import add_volume_weighted_smoothed_field

# %%
# %%time
# Import some FIRE2 data
fname = '/mnt/raid-project/murray/lakhlani/FIRE2_core/m12c_res56000/output/snapshot_600.hdf5'
ds = yt.load(fname)
# The center of the Halo was recovered in another notebook
center_Halo = [25277.66673046,34505.21241664,32868.48520185]
sp = ds.sphere(center_Halo, (10, "kpc"))
ang_mom_sphere = ds.sphere(center_Halo, (0.5, "kpc"))
# Out:
# yt : [INFO     ] 2020-05-20 16:07:25,810 Calculating time from 1.000e+00 to be 4.355e+17 seconds
# yt : [INFO     ] 2020-05-20 16:07:25,811 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2020-05-20 16:07:25,848 Parameters: current_time              = 4.3545571088051386e+17 s
# yt : [INFO     ] 2020-05-20 16:07:25,849 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2020-05-20 16:07:25,850 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-05-20 16:07:25,851 Parameters: domain_right_edge         = [60000. 60000. 60000.]
# yt : [INFO     ] 2020-05-20 16:07:25,852 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2020-05-20 16:07:25,853 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2020-05-20 16:07:25,853 Parameters: omega_lambda              = 0.728
# yt : [INFO     ] 2020-05-20 16:07:25,854 Parameters: omega_matter              = 0.272
# yt : [INFO     ] 2020-05-20 16:07:25,855 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2020-05-20 16:07:25,856 Parameters: hubble_constant           = 0.702
# yt : [INFO     ] 2020-05-20 16:07:25,864 Allocating for 4.150e+07 particles (index particle type 'all')
# yt : [INFO     ] 2020-05-20 16:07:34,522 Identified 2.680e+06 octs
# CPU times: user 8.97 s, sys: 1.92 s, total: 10.9 s
# Wall time: 10.9 s

# %%
def find_normal_vector():
    # Finds the galaxy's normal vector by averaging the angular momentas
    # of the particles
    angular_momentum =[np.mean(ang_mom_sphere['angular_momentum_x']),
                       np.mean(ang_mom_sphere['angular_momentum_y']),
                       np.mean(ang_mom_sphere['angular_momentum_z'])]
    normalized_ang = np.array(angular_momentum)/np.linalg.norm(angular_momentum)
    print(normalized_ang)

# %%
# Define a few vectors. parr is along the galaxy plane. 
# Perp is perpendicular to the galaxy plane
norm_perp = np.array([0.91752181,-0.21788365,-0.33268671])
norm_parr = np.array([-0.21788365,-0.91752181,0])/np.linalg.norm([-0.21788365,-0.91752181,0])

# %%
# Creates the field which will be required to compute the dispersion measure
def _ElectronDensity(field, data):
    xh= 1. - data['PartType0','Metallicity_00'] - data['PartType0','Metallicity_01']
    ne= xh * data['PartType0','Density'] * data['PartType0','ElectronAbundance'] / mp
    return ne
# Adds the field to the data set
ds.add_field(('PartType0', '_ElectronDensity'), function = _ElectronDensity, 
             sampling_type = 'particle', units='1/cm**3')

# smooths a particle field into a continuous field
fn = add_volume_weighted_smoothed_field(
      "PartType0", "particle_position", "particle_mass", "smoothing_length",
      "density", "_ElectronDensity",ds.field_info)

# Labels the new field
ds.field_info.alias(('gas', '_ElectronDensity'), fn[0])
ds.derived_field_list.append(('gas', '_ElectronDensity'))

# %%
def make_ray_plots(projection_axis, ray_axis, filename, all_angles = False):
    ''' 
    This function computes the dispersion measure along a light ray
    going through a simulated galaxy.
    Arguments:
    projection_axis: vector perpendicular to the light ray used to make a projection plot
    ray_axis: vector parallel to the light ray
    filename: name inditifer for images
    all_angles: Instead of creating a single off-axis projection plot,
    the function creates three on-axis projection plots when True
    '''
    
    # RAY CREATION
    ray_end = list(np.array(center_Halo) + 4*np.array(ray_axis))
    ray = trident.make_simple_ray(ds,
                                   start_position=center_Halo,
                                    end_position=ray_end,
                                    fields = ['_ElectronDensity','density','temperature'],
                                    data_filename="{}.h5".format(filename))
    
    # GALAXY PLOTS
    if all_angles:
        # Creates three on-axis projection plots
        axes=['x','y','z']
        for axis in axes:
            prj_x = yt.ProjectionPlot(ds, axis, 'density', width=10*kpc, data_source = sp,
                                      center=center_Halo)
            prj_x.annotate_ray(ray)
            prj_x.save(filename+'_galaxy_{}.pdf'.format(str(axis)))
        
    else:
        image = yt.OffAxisProjectionPlot(ds, projection_axis, fields= 'density', 
                                         center= center_Halo, width=10, data_source = sp)
        image.annotate_ray(ray)
        image.save(filename+'_galaxy.pdf')
    
        # COMPUTING THE DM
        length = np.linalg.norm(np.array(center_Halo)-np.array(ray_end))
        int_elec_dens = []
        int_total = 0
        # Finding the entry where arc_length>1kpc:
        for i in range(len(ray.data['_ElectronDensity'])):
            # Convert in pc/cm^-3
            int_total += ray.data['_ElectronDensity'][i]*ray.data['dl'][i]*60000*1000
            int_elec_dens.append(float(int_total))
        
        # LIGHT RAY DATA PLOTS
        fig, axs = pl.subplots(2,2)

        axs[0,0].plot(np.linspace(0,length,len(ray.data['density'])), 
                      np.log10(ray.data['density']))
        axs[0,0].set_xlabel('Arc Length (kpc)')
        axs[0,0].set_ylabel('Density '+r'$\log\left(\frac{g}{cm^3}\right)$')

        axs[0,1].plot(np.linspace(0,length,len(ray.data['temperature'])), 
                      np.log10(ray.data['temperature']))
        axs[0,1].set_xlabel('Arc Length (kpc)')
        axs[0,1].set_ylabel('Temperature '+r'$\log(K)$')

        axs[1,0].plot(np.linspace(0,length,len(ray.data['_ElectronDensity'])), 
                np.log10(ray.data['_ElectronDensity']))
        axs[1,0].set_xlabel('Arc Length (kpc)')
        axs[1,0].set_ylabel('Electron Density '+r'$\log(cm^{-3})$')

        axs[1,1].plot(np.linspace(0,length,len(int_elec_dens)), np.log10(int_elec_dens))
        axs[1,1].set_xlabel('Arc Length (kpc)')
        axs[1,1].set_ylabel('DM '+r'$\log(cm^{-2})$')

        pl.subplots_adjust(left = 0.20,right = 0.9,bottom = 0.2,top = 0.9,
                           wspace = 0.4,hspace = 0.8)
        fig.savefig(filename+'_subplots.pdf')
    return ray

# %%
# %%time
ray_parr = make_ray_plots(norm_perp, norm_parr, 'ray_parr')
# Out:
# yt : [INFO     ] 2020-05-20 16:07:36,694 Getting segment at z = 0.0: [0.42129445 0.57508687 0.54780809] unitary to [0.42127904 0.57502201 0.54780809] unitary.
# /home/hlamarre/.local/lib/python3.7/site-packages/yt/units/yt_array.py:1417: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# /home/hlamarre/.local/lib/python3.7/site-packages/yt/units/yt_array.py:1417: RuntimeWarning: invalid value encountered in less
#   out=out, **kwargs)
# yt : [INFO     ] 2020-05-20 16:07:36,698 Getting subsegment: [0.4212944455076667 unitary, 0.5750868736106668 unitary, 0.5478080866975 unitary] to [0.42127904253795223 unitary, 0.5750220107324665 unitary, 0.5478080866975 unitary].
# yt : [INFO     ] 2020-05-20 16:10:43,585 Saving field data to yt dataset: ray_parr.h5.
# yt : [INFO     ] 2020-05-20 16:10:43,791 Parameters: current_time              = 4.3545571088051386e+17 s
# yt : [INFO     ] 2020-05-20 16:10:43,791 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2020-05-20 16:10:43,792 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2020-05-20 16:10:43,793 Parameters: domain_right_edge         = [60000. 60000. 60000.] code_length
# yt : [INFO     ] 2020-05-20 16:10:43,794 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2020-05-20 16:10:43,795 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2020-05-20 16:10:43,796 Parameters: omega_lambda              = 0.728
# yt : [INFO     ] 2020-05-20 16:10:43,796 Parameters: omega_matter              = 0.272
# yt : [ERROR    ] 2020-05-20 16:10:43,797 Missing omega_radiation in parameter file definition!
# yt : [INFO     ] 2020-05-20 16:10:43,798 Parameters: hubble_constant           = 0.702
# yt : [INFO     ] 2020-05-20 16:10:43,803 xlim = -5.000000 5.000000
# yt : [INFO     ] 2020-05-20 16:10:43,804 ylim = -5.000000 5.000000
# yt : [INFO     ] 2020-05-20 16:10:43,805 zlim = -30000.000000 30000.000000
# yt : [INFO     ] 2020-05-20 16:10:43,806 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2020-05-20 16:11:40,531 Saving plot ray_parr_galaxy.pdf
# yt : [INFO     ] 2020-05-20 16:11:40,977 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:40,985 Allocating for 1.100e+02 particles (index particle type 'all')
# yt : [INFO     ] 2020-05-20 16:11:40,993 Identified 2.010e+02 octs
# yt : [INFO     ] 2020-05-20 16:11:41,221 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,228 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,237 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,243 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,252 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,262 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,272 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,278 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,285 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,294 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,305 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,316 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,327 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,337 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,347 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,357 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,368 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,378 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,389 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,400 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,412 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,420 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,427 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,433 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,442 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,451 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,466 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,472 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,479 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,486 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,492 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,500 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,510 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,520 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,531 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,541 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,554 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,564 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,575 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,586 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,596 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,607 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,618 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,626 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,633 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,641 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,650 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,660 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,671 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,681 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,692 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,703 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,714 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,724 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,735 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,745 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,756 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,766 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,778 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,788 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,799 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,809 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,820 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,830 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,842 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,852 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,863 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,873 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,884 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,894 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,905 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,916 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,927 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,937 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,948 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,958 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,969 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,979 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:41,991 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,001 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,012 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,022 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,033 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,043 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,055 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,065 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,076 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,086 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,097 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,108 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,118 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,129 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,140 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,150 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,161 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,171 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,182 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,192 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,204 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,214 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,225 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,235 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,246 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,256 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,267 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,278 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,289 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,299 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,310 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,320 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,331 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,342 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,353 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,363 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,374 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,384 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,395 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,406 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,417 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,427 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,438 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,448 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,459 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,470 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,481 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,491 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,502 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,513 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,523 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,534 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,545 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,555 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,566 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,577 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,587 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,598 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,609 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,619 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,630 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,640 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,651 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,661 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,672 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,683 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,694 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,704 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,715 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,725 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,736 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,746 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,757 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,768 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,779 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,789 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,800 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,810 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,821 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,831 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,842 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,853 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,863 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,874 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,884 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,895 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,906 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,917 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,927 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,938 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,948 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,959 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,974 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,984 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:42,995 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,005 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,016 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,027 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,037 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,048 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,059 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,069 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,080 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,090 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,101 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,112 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,123 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,133 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,144 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,154 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,165 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,176 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,187 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,197 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,208 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,218 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,230 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,240 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,251 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,261 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,272 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,283 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,294 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,304 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,315 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,325 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,336 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,347 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,358 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,368 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,379 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,389 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,400 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,411 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,421 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,432 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,443 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,453 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,464 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,475 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,486 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,497 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,662 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,671 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,680 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,688 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,698 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:11:43,705 Returning an all_data data container.
# CPU times: user 2min 43s, sys: 1min 23s, total: 4min 7s
# Wall time: 4min 7s

# %%
# %%time
ray_perp = make_ray_plots(norm_parr, norm_perp, 'ray_perp')
# Out:
# yt : [INFO     ] 2020-05-20 16:12:43,741 Getting segment at z = 0.0: [0.42129445 0.57508687 0.54780809] unitary to [0.42135561 0.57507235 0.54778591] unitary.
# yt : [INFO     ] 2020-05-20 16:12:43,743 Getting subsegment: [0.4212944455076667 unitary, 0.5750868736106668 unitary, 0.5478080866975 unitary] to [0.421355613628218 unitary, 0.5750723480340274 unitary, 0.5477859075835418 unitary].
# yt : [INFO     ] 2020-05-20 16:15:48,548 Saving field data to yt dataset: ray_perp.h5.
# yt : [INFO     ] 2020-05-20 16:15:48,736 Parameters: current_time              = 4.3545571088051386e+17 s
# yt : [INFO     ] 2020-05-20 16:15:48,737 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2020-05-20 16:15:48,737 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2020-05-20 16:15:48,738 Parameters: domain_right_edge         = [60000. 60000. 60000.] code_length
# yt : [INFO     ] 2020-05-20 16:15:48,739 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2020-05-20 16:15:48,740 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2020-05-20 16:15:48,741 Parameters: omega_lambda              = 0.728
# yt : [INFO     ] 2020-05-20 16:15:48,742 Parameters: omega_matter              = 0.272
# yt : [ERROR    ] 2020-05-20 16:15:48,742 Missing omega_radiation in parameter file definition!
# yt : [INFO     ] 2020-05-20 16:15:48,743 Parameters: hubble_constant           = 0.702
# yt : [INFO     ] 2020-05-20 16:15:48,750 xlim = -5.000000 5.000000
# yt : [INFO     ] 2020-05-20 16:15:48,751 ylim = -5.000000 5.000000
# yt : [INFO     ] 2020-05-20 16:15:48,751 zlim = -30000.000000 30000.000000
# yt : [INFO     ] 2020-05-20 16:15:48,753 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2020-05-20 16:16:42,774 Saving plot ray_perp_galaxy.pdf
# yt : [INFO     ] 2020-05-20 16:16:43,351 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,362 Allocating for 8.600e+01 particles (index particle type 'all')
# yt : [INFO     ] 2020-05-20 16:16:43,368 Identified 1.690e+02 octs
# yt : [INFO     ] 2020-05-20 16:16:43,697 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,704 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,712 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,720 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,728 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,736 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,744 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,751 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,759 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,767 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,775 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,782 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,790 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,797 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,807 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,814 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,822 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,829 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,837 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,844 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,852 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,861 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,869 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,876 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,883 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,891 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,898 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,906 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,913 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,921 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,928 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,936 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,943 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,950 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,958 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,965 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,973 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,981 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,989 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:43,996 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,004 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,011 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,019 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,026 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,034 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,041 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,049 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,056 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,063 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,071 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,078 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,086 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,093 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,101 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,109 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,117 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,124 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,131 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,138 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,149 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,157 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,164 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,170 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,177 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,186 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,198 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,208 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,215 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,223 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,231 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,239 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,246 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,254 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,262 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,269 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,277 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,285 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,292 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,300 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,307 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,315 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,322 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,330 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,338 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,346 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,353 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,361 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,369 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,377 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,384 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,392 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,399 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,407 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,415 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,422 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,430 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,438 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,446 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,454 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,461 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,469 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,477 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,485 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,493 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,501 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,509 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,517 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,525 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,533 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,541 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,549 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,556 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,564 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,572 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,579 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,587 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,597 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,607 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,618 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,628 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,639 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,649 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,660 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,671 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,681 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,692 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,703 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,713 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,724 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,735 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,745 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,756 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,766 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,777 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,788 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,798 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,809 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,819 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,830 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,841 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,851 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,862 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,872 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,883 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,894 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,904 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,915 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,925 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,936 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,947 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,958 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,968 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,979 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:44,990 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,000 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,011 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,022 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,032 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,043 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,053 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,064 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,074 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,085 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,096 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,106 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,117 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,127 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,138 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,148 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,159 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,170 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,180 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,277 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,283 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,295 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,305 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,319 Returning an all_data data container.
# yt : [INFO     ] 2020-05-20 16:16:45,330 Returning an all_data data container.
# CPU times: user 2min 39s, sys: 1min 22s, total: 4min 1s
# Wall time: 4min 1s
